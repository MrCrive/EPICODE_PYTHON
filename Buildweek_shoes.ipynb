# %%
import pandas as pd

# %%
scarpe = pd.read_csv("Shoe prices.csv")
scarpe
# Out:
#             Brand              Model        Type Gender    Size      Color  \
# 0            Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 1          Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 2          Reebok    Classic Leather      Casual    Men   US 11      White
# 3        Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 4            Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...           ...                ...         ...    ...     ...        ...
# 1001  New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1002        Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1003         Fila           Venom 94     Fashion  Women  US 7.5      White
# 1004     Skechers            Summits    Training    Men    US 8       Grey
# 1005         Nike         Air Max 97     Running  Women  US 7.5     Silver
#
#        Material Price (USD)
# 0       Leather    $170.00
# ...

# %%
awlab = pd.read_csv("C:/Users/HP/Python/Buildweek_Python/AWLab_sales.csv")

# %%
footlocker = pd.read_csv("C:/Users/HP/Python/Buildweek_Python/FootLocker_sales.csv")

# %%
scarpe = scarpe.reset_index()

# %%
scarpe["index"] = scarpe["index"] + 1

# %%
scarpe
# Out:
#       index        Brand              Model        Type Gender    Size  \
# 0         1         Nike       Air Jordan 1  Basketball    Men   US 10
# 1         2       Adidas     Ultra Boost 21     Running    Men  US 9.5
# 2         3       Reebok    Classic Leather      Casual    Men   US 11
# 3         4     Converse       Chuck Taylor      Casual  Women    US 8
# 4         5         Puma       Future Rider   Lifestyle  Women  US 7.5
# ...     ...          ...                ...         ...    ...     ...
# 1001   1002  New Balance  Fresh Foam 880v11     Running  Women   US 10
# 1002   1003        Asics    Gel-Kayano Lite     Running    Men  US 9.5
# 1003   1004         Fila           Venom 94     Fashion  Women  US 7.5
# 1004   1005     Skechers            Summits    Training    Men    US 8
# 1005   1006         Nike         Air Max 97     Running  Women  US 7.5
#
#           Color   Material Price (USD)
# 0     Red/Black    Leather    $170.00
# ...

# %%
scarpe = scarpe.set_index("index")

# %%
scarpe
# Out:
#              Brand              Model        Type Gender    Size      Color  \
# index
# 1             Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 2           Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 3           Reebok    Classic Leather      Casual    Men   US 11      White
# 4         Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 5             Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...            ...                ...         ...    ...     ...        ...
# 1002   New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1003         Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1004          Fila           Venom 94     Fashion  Women  US 7.5      White
# 1005      Skechers            Summits    Training    Men    US 8       Grey
# 1006          Nike         Air Max 97     Running  Women  US 7.5     Silver
#
#         Material Price (USD)
# index
# ...

# %%
awlab
# Out:
#             Brand              Model        Type Gender    Size      Color  \
# 0            Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 1          Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 2          Reebok    Classic Leather      Casual    Men   US 11      White
# 3        Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 4            Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...           ...                ...         ...    ...     ...        ...
# 1001  New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1002        Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1003         Fila           Venom 94     Fashion  Women  US 7.5      White
# 1004     Skechers            Summits    Training    Men    US 8       Grey
# 1005         Nike         Air Max 97     Running  Women  US 7.5     Silver
#
# ...

# %%
footlocker
# Out:
#             Brand              Model        Type Gender    Size      Color  \
# 0            Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 1          Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 2          Reebok    Classic Leather      Casual    Men   US 11      White
# 3        Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 4            Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...           ...                ...         ...    ...     ...        ...
# 1001  New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1002        Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1003         Fila           Venom 94     Fashion  Women  US 7.5      White
# 1004     Skechers            Summits    Training    Men    US 8       Grey
# 1005         Nike         Air Max 97     Running  Women  US 7.5     Silver
#
# ...

# %%
awlab['Selling Price'] = awlab['Selling Price'].str.replace('$','')
footlocker['Selling Price'] = footlocker['Selling Price'].str.replace('$', '')
footlocker['Price (USD)'] = footlocker['Price (USD)'].str.replace('$', '')
awlab['Price (USD)'] = awlab['Price (USD)'].str.replace('$', '')

# %%
awlab
# Out:
#             Brand              Model        Type Gender    Size      Color  \
# 0            Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 1          Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 2          Reebok    Classic Leather      Casual    Men   US 11      White
# 3        Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 4            Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...           ...                ...         ...    ...     ...        ...
# 1001  New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1002        Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1003         Fila           Venom 94     Fashion  Women  US 7.5      White
# 1004     Skechers            Summits    Training    Men    US 8       Grey
# 1005         Nike         Air Max 97     Running  Women  US 7.5     Silver
#
# ...

# %%
awlab = awlab.reset_index()
awlab["index"] += 1
awlab = awlab.set_index("index")

# %%
awlab
# Out:
#              Brand              Model        Type Gender    Size      Color  \
# index
# 1             Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 2           Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 3           Reebok    Classic Leather      Casual    Men   US 11      White
# 4         Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 5             Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...            ...                ...         ...    ...     ...        ...
# 1002   New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1003         Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1004          Fila           Venom 94     Fashion  Women  US 7.5      White
# 1005      Skechers            Summits    Training    Men    US 8       Grey
# 1006          Nike         Air Max 97     Running  Women  US 7.5     Silver
#
# ...

# %%
footlocker = footlocker.reset_index()
footlocker["index"] += 1
footlocker = footlocker.set_index("index")

# %%
footlocker
# Out:
#              Brand              Model        Type Gender    Size      Color  \
# index
# 1             Nike       Air Jordan 1  Basketball    Men   US 10  Red/Black
# 2           Adidas     Ultra Boost 21     Running    Men  US 9.5      Black
# 3           Reebok    Classic Leather      Casual    Men   US 11      White
# 4         Converse       Chuck Taylor      Casual  Women    US 8       Navy
# 5             Puma       Future Rider   Lifestyle  Women  US 7.5       Pink
# ...            ...                ...         ...    ...     ...        ...
# 1002   New Balance  Fresh Foam 880v11     Running  Women   US 10       Grey
# 1003         Asics    Gel-Kayano Lite     Running    Men  US 9.5      Black
# 1004          Fila           Venom 94     Fashion  Women  US 7.5      White
# 1005      Skechers            Summits    Training    Men    US 8       Grey
# 1006          Nike         Air Max 97     Running  Women  US 7.5     Silver
#
# ...

# %%
aw_brand_items = awlab.groupby("Brand")["Number of Items Sold"].sum()
aw_brand_items = aw_brand_items.sort_values()
aw_brand_items.plot(kind="barh")
# Out:
# <Axes: ylabel='Brand'>

# %%
ft_brand_items = footlocker.groupby("Brand")["Number of Items Sold"].sum()
ft_brand_items = ft_brand_items.sort_values()
ft_brand_items.plot(kind="barh")
# Out:
# <Axes: ylabel='Brand'>

# %%
aw_type_items = awlab.groupby("Type")["Number of Items Sold"].sum()
aw_type_items = aw_type_items.sort_values()
aw_type_items.plot(kind="barh")
# Out:
# <Axes: ylabel='Type'>

# %%
ft_type_items = footlocker.groupby("Type")["Number of Items Sold"].sum()
ft_type_items = ft_type_items.sort_values()
ft_type_items.plot(kind="barh")
# Out:
# <Axes: ylabel='Type'>

# %%
awlab["Selling Price"] = awlab["Selling Price"].astype(float)

# %%
footlocker["Selling Price"] = footlocker["Selling Price"].astype(float)

# %%
awlab_describe = awlab.groupby("Brand")["Selling Price"].describe()
awlab_describe = awlab_describe.loc[:,["mean","min","max"]]
awlab_describe = awlab_describe.sort_values(by = "mean")
awlab_describe.plot(kind = "barh")
# Out:
# <Axes: ylabel='Brand'>

# %%
footlocker_describe = footlocker.groupby("Brand")["Selling Price"].describe()
footlocker_describe = footlocker_describe.loc[:,["mean","min","max"]]
footlocker_describe = footlocker_describe.sort_values(by = "mean")
footlocker_describe.plot(kind = "barh")
# Out:
# <Axes: ylabel='Brand'>

# %%
aw_type_describe = awlab.groupby("Type")["Selling Price"].describe()
aw_type_describe = aw_type_describe.loc[:,["mean","min","max"]]
aw_type_describe = aw_type_describe.sort_values(by = "mean")
aw_type_describe.plot(kind = "barh")
# Out:
# <Axes: ylabel='Type'>

# %%
ft_type_describe = footlocker.groupby("Type")["Selling Price"].describe()
ft_type_describe = ft_type_describe.loc[:,["mean","min","max"]]
ft_type_describe = ft_type_describe.sort_values(by = "mean")
ft_type_describe.plot(kind = "barh")
# Out:
# <Axes: ylabel='Type'>

# %%
aw_size_item = awlab.groupby("Size")["Number of Items Sold"].sum()
aw_size_item = aw_size_item.sort_values()
aw_size_item.plot(kind="barh")
# Out:
# <Axes: ylabel='Size'>

# %%
ft_size_item = footlocker.groupby("Size")["Number of Items Sold"].sum()
ft_size_item = ft_size_item.sort_values()
ft_size_item.plot(kind="barh")
# Out:
# <Axes: ylabel='Size'>

# %%
aw_color_item = awlab.groupby("Color")["Number of Items Sold"].sum()
aw_color_item = aw_color_item.sort_values()
aw_color_item.plot(kind="barh", figsize=[10,20])
# Out:
# <Axes: ylabel='Color'>

# %%
ft_color_item = footlocker.groupby("Color")["Number of Items Sold"].sum()
ft_color_item = ft_color_item.sort_values()
ft_color_item.plot(kind="barh",figsize=[10,20])
# Out:
# <Axes: ylabel='Color'>

# %%
aw_city = awlab.groupby("City")["City"].count()
aw_city = aw_city.sort_values()
aw_city.plot(kind="barh")
# Out:
# <Axes: ylabel='City'>

# %%
ft_city = awlab.groupby("City")["City"].count()
ft_city = ft_city.sort_values()
ft_city.plot(kind = "barh")
# Out:
# <Axes: ylabel='City'>
